# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import warnings; warnings.simplefilter("ignore", category=xr.SerializationWarning)

# %%
MISSION_NUMBER=32
OUTPUT=f'../missions/output/{MISSION_NUMBER}/ocean_dunex_his.nc'
ds = xr.load_dataset(OUTPUT).isel(ocean_time=-1)
ds
# Out:
# <xarray.Dataset>
# Dimensions:          (tracer: 1, s_rho: 8, s_w: 9, eta_rho: 1001, xi_rho: 901,
#                       eta_u: 1001, xi_u: 900, eta_v: 1000, xi_v: 901,
#                       eta_psi: 1000, xi_psi: 900)
# Coordinates:
#   * s_rho            (s_rho) float64 -0.9375 -0.8125 -0.6875 ... -0.1875 -0.0625
#   * s_w              (s_w) float64 -1.0 -0.875 -0.75 -0.625 ... -0.25 -0.125 0.0
#     x_rho            (eta_rho, xi_rho) float64 50.0 51.0 52.0 ... 949.0 950.0
#     y_rho            (eta_rho, xi_rho) float64 -1.2e+03 -1.2e+03 ... 1.8e+03
#     x_u              (eta_u, xi_u) float64 50.5 51.5 52.5 ... 947.5 948.5 949.5
#     y_u              (eta_u, xi_u) float64 -1.2e+03 -1.2e+03 ... 1.8e+03 1.8e+03
#     x_v              (eta_v, xi_v) float64 50.0 51.0 52.0 ... 948.0 949.0 950.0
#     y_v              (eta_v, xi_v) float64 -1.198e+03 -1.198e+03 ... 1.798e+03
#     x_psi            (eta_psi, xi_psi) float64 50.5 51.5 52.5 ... 948.5 949.5
# ...

# %%
ds.isel(s_rho=-1).Wave_break.plot(norm=ml.colors.)

# %%
ds.isel(s_rho=0).vbar.plot()

# %%
ds.Hwave.plot()

# %%
ds.tke.mean(dim='s_w').plot()
